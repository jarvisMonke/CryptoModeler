# %%
import sys
import os
import json
from importlib import reload  # Import the reload function

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import utils.tuning as tn

reload(tn)
# %load_ext autoreload
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Define your configuration
timeframe_filenames = {
    "1m": "../data/raw/ETHUSDT_1m_v600k.csv",
    "3m": "../data/raw/ETHUSDT_3m_v600k.csv",
    "5m": "../data/DOGEUSDT_5m_v0.csv",
    "15m": "../data/DOGEUSDT_15m_v0.csv",
    "30m": "../data/DOGEUSDT_30m_v0.csv"
}
config = {
    "epochs": 50,
    "trials": 150,
    "window_size": 80,
    "look_ahead_size": 20,
    "crypto": "ETHUSDT",
    "timeframe": "1m",
    "timeframe_filenames": timeframe_filenames,
    "train_size": 3000,
    "val_size": 500,
    "step_size": 200,
}

new = True
# Manage the study
study_name = "study_0"
study, config = tn.manage_optuna_study(study_name, config, delete_existing=new)

# Optimize the study with the configuration dictionary
study.optimize(lambda trial: tn.objective(trial, config), n_trials=config["trials"])

print("Best parameters:", study.best_params)

# Save the best parameters in a JSON file
file_path = f'../optuna/{study_name}/best_params.json'
with open(file_path, 'w') as f:
    json.dump(study.best_params, f, indent=4)
# Out:
# Deleted existing study 'study_0' at ../optuna/study_0/study.db
# Deleted existing configuration for 'study_0' at ../optuna/study_0/config.json
# [I 2025-01-07 23:25:55,418] A new study created in RDB with name: study_0
# Created new study 'study_0' at ../optuna/study_0/study.db
# Saved new configuration for study 'study_0':
# {
#     "epochs": 50,
#     "trials": 150,
#     "window_size": 80,
#     "look_ahead_size": 20,
#     "crypto": "ETHUSDT",
#     "timeframe": "1m",
#     "timeframe_filenames": {
#         "1m": "../data/raw/ETHUSDT_1m_v600k.csv",
#         "3m": "../data/raw/ETHUSDT_3m_v600k.csv",
#         "5m": "../data/DOGEUSDT_5m_v0.csv",
#         "15m": "../data/DOGEUSDT_15m_v0.csv",
#         "30m": "../data/DOGEUSDT_30m_v0.csv"
#     },
#     "train_size": 3000,
#     "val_size": 500,
#     "step_size": 200
# }
# Dataset loaded from ../data/raw/ETHUSDT_1m_v600k.csv.
# Trial Hyperparams: {'lstm_units_1': 256, 'lstm_units_2': 128, 'dropout': 0.2, 'learning_rate': 0.0018702616942438612, 'batch_size': 128, 'dense_units': 128, 'sequence_length': 10, 'gradient_clipping': 0.5, 'optimizer': 'rmsprop', 'activation': 'relu', 'num_indicators': 26, 'scaler_type': 'RobustScaler', 'window_size': 80, 'look_ahead_size': 20, 'crypto': 'ETHUSDT', 'timeframe': '1m', 'timeframe_filenames': {'1m': '../data/raw/ETHUSDT_1m_v600k.csv', '3m': '../data/raw/ETHUSDT_3m_v600k.csv', '5m': '../data/DOGEUSDT_5m_v0.csv', '15m': '../data/DOGEUSDT_15m_v0.csv', '30m': '../data/DOGEUSDT_30m_v0.csv'}}
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 210ms/step - loss: 14243305554444288.0000 - mae: 11735151.0000 - val_loss: 1570476937707520.0000 - val_mae: 13782778.0000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1262329543000064.0000 - mae: 6711269.5000 - val_loss: 728250432.0000 - val_mae: 11230.4414
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 68122492928.0000 - mae: 67356.2812 - val_loss: 357244672.0000 - val_mae: 6132.4907
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 10438952615936.0000 - mae: 362119.5312 - val_loss: 13715812352.0000 - val_mae: 33561.8828
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 27514262725328896.0000 - mae: 20595016.0000 - val_loss: 25878066.0000 - val_mae: 1230.2745
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 7763314053656608768.0000 - mae: 238393328.0000 - val_loss: 23.8660 - val_mae: 3.0271
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1224879360.0000 - mae: 1285.7004 - val_loss: 44309.0234 - val_mae: 91.2757
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1271267072.0000 - mae: 1228.6550 - val_loss: 292914.4062 - val_mae: 228.1148
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4353160192.0000 - mae: 5453.4551 - val_loss: 196548.5625 - val_mae: 55.6668
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 7718.3823 - mae: 26.5587 - val_loss: 9859740.0000 - val_mae: 594.9755
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 454218720.0000 - mae: 3138.8035 - val_loss: 3925.9150 - val_mae: 23.6365
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 50102160.0000 - mae: 557.8781 - val_loss: 177826.4062 - val_mae: 203.2613
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 117062560.0000 - mae: 1731.4437 - val_loss: 1792511.5000 - val_mae: 551.6594
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 742851648.0000 - mae: 3323.7092 - val_loss: 96240844800.0000 - val_mae: 111798.9609
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 44476166144.0000 - mae: 41639.0000 - val_loss: 467893.5000 - val_mae: 296.1956
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 451839.6250 - mae: 152.6645 - val_loss: 2957745.5000 - val_mae: 466.1857
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# [I 2025-01-07 23:27:38,065] Trial 0 finished with value: 68.77380959601075 and parameters: {'lstm_units_1': 256, 'lstm_units_2': 128, 'dropout': 0.2, 'learning_rate': 0.0018702616942438612, 'batch_size': 128, 'dense_units': 128, 'sequence_length': 10, 'gradient_clipping': 0.5, 'optimizer': 'rmsprop', 'activation': 'relu', 'num_indicators': 26, 'scaler_type': 'RobustScaler'}. Best is trial 0 with value: 68.77380959601075.
# Dataset loaded from ../data/raw/ETHUSDT_1m_v600k.csv.
# Trial Hyperparams: {'lstm_units_1': 128, 'lstm_units_2': 64, 'dropout': 0.2, 'learning_rate': 0.00019050353502528632, 'batch_size': 32, 'dense_units': 16, 'sequence_length': 10, 'gradient_clipping': 2.0, 'optimizer': 'rmsprop', 'activation': 'tanh', 'num_indicators': 9, 'scaler_type': 'StandardScaler', 'window_size': 80, 'look_ahead_size': 20, 'crypto': 'ETHUSDT', 'timeframe': '1m', 'timeframe_filenames': {'1m': '../data/raw/ETHUSDT_1m_v600k.csv', '3m': '../data/raw/ETHUSDT_3m_v600k.csv', '5m': '../data/DOGEUSDT_5m_v0.csv', '15m': '../data/DOGEUSDT_15m_v0.csv', '30m': '../data/DOGEUSDT_30m_v0.csv'}}
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.2619 - mae: 0.3929 - val_loss: 0.0199 - val_mae: 0.1091
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0458 - mae: 0.1679 - val_loss: 0.0088 - val_mae: 0.0731
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0239 - mae: 0.1214 - val_loss: 0.0049 - val_mae: 0.0530
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0138 - mae: 0.0911 - val_loss: 0.0029 - val_mae: 0.0392
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0087 - mae: 0.0724 - val_loss: 0.0019 - val_mae: 0.0316
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0067 - mae: 0.0618 - val_loss: 0.0018 - val_mae: 0.0295
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0052 - mae: 0.0548 - val_loss: 0.0020 - val_mae: 0.0299
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0042 - mae: 0.0473 - val_loss: 0.0029 - val_mae: 0.0347
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0035 - mae: 0.0437 - val_loss: 0.0028 - val_mae: 0.0348
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0036 - mae: 0.0438 - val_loss: 0.0026 - val_mae: 0.0357
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0033 - mae: 0.0414 - val_loss: 0.0026 - val_mae: 0.0371
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0030 - mae: 0.0400 - val_loss: 0.0028 - val_mae: 0.0373
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0029 - mae: 0.0389 - val_loss: 0.0047 - val_mae: 0.0393
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0029 - mae: 0.0378 - val_loss: 0.0049 - val_mae: 0.0404
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0056 - mae: 0.0503 - val_loss: 0.0031 - val_mae: 0.0363
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0051 - mae: 0.0489 - val_loss: 0.0040 - val_mae: 0.0410
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0049 - mae: 0.0470 - val_loss: 0.0038 - val_mae: 0.0413
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0046 - mae: 0.0456 - val_loss: 0.0027 - val_mae: 0.0348
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0041 - mae: 0.0437 - val_loss: 0.0024 - val_mae: 0.0329
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0045 - mae: 0.0451 - val_loss: 0.0022 - val_mae: 0.0298
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0039 - mae: 0.0428 - val_loss: 0.0023 - val_mae: 0.0304
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0047 - mae: 0.0453 - val_loss: 0.0021 - val_mae: 0.0285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0059 - mae: 0.0460 - val_loss: 0.0074 - val_mae: 0.0404
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0050 - mae: 0.0456 - val_loss: 0.0099 - val_mae: 0.0500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0049 - mae: 0.0454 - val_loss: 0.0043 - val_mae: 0.0405
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0043 - mae: 0.0436 - val_loss: 0.0021 - val_mae: 0.0337
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0051 - mae: 0.0432 - val_loss: 0.0018 - val_mae: 0.0280
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - mae: 0.0400 - val_loss: 0.0011 - val_mae: 0.0237
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0034 - mae: 0.0386 - val_loss: 0.0012 - val_mae: 0.0229
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0033 - mae: 0.0378 - val_loss: 0.0016 - val_mae: 0.0230
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# [I 2025-01-07 23:30:28,779] Trial 2 finished with value: 0.003120284293635406 and parameters: {'lstm_units_1': 64, 'lstm_units_2': 64, 'dropout': 0.5, 'learning_rate': 0.0002842464064953214, 'batch_size': 64, 'dense_units': 32, 'sequence_length': 10, 'gradient_clipping': 0.5, 'optimizer': 'rmsprop', 'activation': 'tanh', 'num_indicators': 8, 'scaler_type': 'StandardScaler'}. Best is trial 1 with value: 0.0030600915682827638.
# Dataset loaded from ../data/raw/ETHUSDT_1m_v600k.csv.
# Trial Hyperparams: {'lstm_units_1': 128, 'lstm_units_2': 64, 'dropout': 0.5, 'learning_rate': 0.00010830773474615701, 'batch_size': 128, 'dense_units': 16, 'sequence_length': 10, 'gradient_clipping': 2.0, 'optimizer': 'adam', 'activation': 'tanh', 'num_indicators': 29, 'scaler_type': 'MinMaxScaler', 'window_size': 80, 'look_ahead_size': 20, 'crypto': 'ETHUSDT', 'timeframe': '1m', 'timeframe_filenames': {'1m': '../data/raw/ETHUSDT_1m_v600k.csv', '3m': '../data/raw/ETHUSDT_3m_v600k.csv', '5m': '../data/DOGEUSDT_5m_v0.csv', '15m': '../data/DOGEUSDT_15m_v0.csv', '30m': '../data/DOGEUSDT_30m_v0.csv'}}
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.4331 - mae: 0.5451 - val_loss: 0.0510 - val_mae: 0.2023
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.1429 - mae: 0.3000 - val_loss: 0.0182 - val_mae: 0.1130
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0984 - mae: 0.2500 - val_loss: 0.0195 - val_mae: 0.1179
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0809 - mae: 0.2268 - val_loss: 0.0190 - val_mae: 0.1140
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0699 - mae: 0.2105 - val_loss: 0.0151 - val_mae: 0.1053
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0540 - mae: 0.1852 - val_loss: 0.0122 - val_mae: 0.0932
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0477 - mae: 0.1733 - val_loss: 0.0124 - val_mae: 0.0946
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0417 - mae: 0.1601 - val_loss: 0.0137 - val_mae: 0.0993
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0373 - mae: 0.1532 - val_loss: 0.0126 - val_mae: 0.0939
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0357 - mae: 0.1493 - val_loss: 0.0125 - val_mae: 0.0948
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0320 - mae: 0.1408 - val_loss: 0.0108 - val_mae: 0.0857
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0279 - mae: 0.1323 - val_loss: 0.0119 - val_mae: 0.0900
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0269 - mae: 0.1300 - val_loss: 0.0140 - val_mae: 0.0881
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0258 - mae: 0.1245 - val_loss: 0.0150 - val_mae: 0.0919
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0243 - mae: 0.1218 - val_loss: 0.0209 - val_mae: 0.1002
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0230 - mae: 0.1179 - val_loss: 0.0176 - val_mae: 0.0932
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0214 - mae: 0.1146 - val_loss: 0.0167 - val_mae: 0.0882
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0210 - mae: 0.1120 - val_loss: 0.0095 - val_mae: 0.0714
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0212 - mae: 0.1133 - val_loss: 0.0124 - val_mae: 0.0822
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0188 - mae: 0.1077 - val_loss: 0.0151 - val_mae: 0.0901
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0187 - mae: 0.1061 - val_loss: 0.0170 - val_mae: 0.0950
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0179 - mae: 0.1019 - val_loss: 0.0149 - val_mae: 0.0846
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0184 - mae: 0.1043 - val_loss: 0.0077 - val_mae: 0.0633
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0166 - mae: 0.0996 - val_loss: 0.0053 - val_mae: 0.0505
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0164 - mae: 0.0984 - val_loss: 0.0060 - val_mae: 0.0502
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0148 - mae: 0.0936 - val_loss: 0.0071 - val_mae: 0.0568
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0153 - mae: 0.0938
# [W 2025-01-07 23:31:08,903] Trial 3 failed with parameters: {'lstm_units_1': 128, 'lstm_units_2': 64, 'dropout': 0.5, 'learning_rate': 0.00010830773474615701, 'batch_size': 128, 'dense_units': 16, 'sequence_length': 10, 'gradient_clipping': 2.0, 'optimizer': 'adam', 'activation': 'tanh', 'num_indicators': 29, 'scaler_type': 'MinMaxScaler'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_6793/3733939636.py", line 28, in <lambda>
#     study.optimize(lambda trial: tn.objective(trial, config), n_trials=config["trials"])
#   File "/home/jonas/Projects/CryptoModeler/utils/tuning.py", line 85, in objective
#     model, scaler_y = custom_model(model_df, params, tuning=True, trial=trial)
#   File "/home/jonas/Projects/CryptoModeler/utils/modeling.py", line 371, in custom_model
#   File "/home/jonas/Projects/CryptoModeler/utils/modeling.py", line 256, in train
#     - model: The trained model.
#   File "/home/jonas/Projects/CryptoModeler/utils/modeling.py", line 181, in optuna_pruning_and_callbacks
#     def load_model_test_split(filenames, params, model_data_ratio=0.8):
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#     return fn(*args, **kwargs)
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 392, in fit
#     val_logs = self.evaluate(
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#     return fn(*args, **kwargs)
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 479, in evaluate
#     for step, iterator in epoch_iterator:
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 729, in __next__
#     return next(self._epoch_iterator)
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/trainers/epoch_iterator.py", line 112, in _enumerate_iterator
#     self._current_iterator = iter(self._get_iterator())
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 501, in __iter__
#     return iterator_ops.OwnedIterator(self)
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py", line 709, in __init__
#     self._create_iterator(dataset)
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py", line 748, in _create_iterator
#     gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#   File "/home/jonas/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py", line 3478, in make_iterator
#     _result = pywrap_tfe.TFE_Py_FastPathExecute(
# KeyboardInterrupt
# [W 2025-01-07 23:31:08,912] Trial 3 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 28
#      25 study, config = tn.manage_optuna_study(study_name, config, delete_existing=new)
#      27 # Optimize the study with the configuration dictionary
# ---> 28 study.optimize(lambda trial: tn.objective(trial, config), n_trials=config["trials"])
#      30 print("Best parameters:", study.best_params)
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[29], line 28, in <lambda>(trial)
#      25 study, config = tn.manage_optuna_study(study_name, config, delete_existing=new)
#      27 # Optimize the study with the configuration dictionary
# ---> 28 study.optimize(lambda trial: tn.objective(trial, config), n_trials=config["trials"])
#      30 print("Best parameters:", study.best_params)
#
# File ~/Projects/CryptoModeler/utils/tuning.py:85, in objective(trial, config)
#      82 model_df, test_df = load_model_test_split(params['timeframe_filenames'], params)
#      84 print(f'Trial Hyperparams: {params}')
# ---> 85 model, scaler_y = custom_model(model_df, params, tuning=True, trial=trial)
#      87 # Check if the trial is pruned after training
#      88 if trial.should_prune():
#
# File ~/Projects/CryptoModeler/utils/modeling.py:371, in custom_model(df, params, model_name, tuning, trial)
#     368     print('Scalers dumped')
#     370 # Train
# --> 371 model = train(X_train, y_train, params, epochs=50, train_size=3000, val_size=500, step_size=200, tuning=tuning, trial=trial)
#     373 if tuning:
#     374     return model, scaler_y
#
# File ~/Projects/CryptoModeler/utils/modeling.py:256, in train(X, y, params, epochs, train_size, val_size, step_size, tuning, trial)
#     252     break
#     254 if tuning:
#     255     # Call Optuna-specific logic if tuning is enabled
# --> 256     history = optuna_pruning_and_callbacks(trial, model, X_train_epoch, y_train_epoch, X_val_epoch, y_val_epoch, params_grid, epoch_counter, early_stopping)
#     257 else:
#     258     # Train the model without Optuna
#     259     history = model.fit(
#     260         X_train_epoch,
#     261         y_train_epoch,
#    (...)
#     266         callbacks=[early_stopping]
#     267     )
#
# File ~/Projects/CryptoModeler/utils/modeling.py:181, in optuna_pruning_and_callbacks(trial, model, X_train_epoch, y_train_epoch, X_val_epoch, y_val_epoch, params_grid, epoch_counter, early_stopping)
#     175 nan_checker = NaNChecker(trial)
#     177 # Use Optuna's KerasPruningCallback to prune the trial if necessary
#     178 #pruning_callback = KerasPruningCallback(trial, 'val_loss')  # Monitor 'val_loss' for pruning
#     179
#     180 # Now train the same model on the new data for this epoch (do not reinitialize model)
# --> 181 history = model.fit(
#     182     X_train_epoch,
#     183     y_train_epoch,
#     184     epochs=1,  # Train for 1 epoch at a time in this loop
#     185     batch_size=params_grid["batch_size"],
#     186     validation_data=(X_val_epoch, y_val_epoch),  # Provide the new validation data
#     187     verbose=1,
#     188     callbacks=[early_stopping, nan_checker] #, pruning_callback]
#     189 )
#     191 # Check if Optuna should prune the trial
#     192 if trial.should_prune():
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:392, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     381 if getattr(self, "_eval_epoch_iterator", None) is None:
#     382     self._eval_epoch_iterator = TFEpochIterator(
#     383         x=val_x,
#     384         y=val_y,
#    (...)
#     390         shuffle=False,
#     391     )
# --> 392 val_logs = self.evaluate(
#     393     x=val_x,
#     394     y=val_y,
#     395     sample_weight=val_sample_weight,
#     396     batch_size=validation_batch_size or batch_size,
#     397     steps=validation_steps,
#     398     callbacks=callbacks,
#     399     return_dict=True,
#     400     _use_cached_eval_dataset=True,
#     401 )
#     402 val_logs = {
#     403     "val_" + name: val for name, val in val_logs.items()
#     404 }
#     405 epoch_logs.update(val_logs)
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:479, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     477 self.reset_metrics()
#     478 with epoch_iterator.catch_stop_iteration():
# --> 479     for step, iterator in epoch_iterator:
#     480         callbacks.on_test_batch_begin(step)
#     481         logs = self.test_function(iterator)
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:729, in TFEpochIterator.__next__(self)
#     728 def __next__(self):
# --> 729     return next(self._epoch_iterator)
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/keras/src/trainers/epoch_iterator.py:112, in EpochIterator._enumerate_iterator(self)
#     110         yield step, self._current_iterator
#     111     if self._num_batches and self._steps_seen >= self._num_batches:
# --> 112         self._current_iterator = iter(self._get_iterator())
#     113         self._steps_seen = 0
#     114 else:
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/Projects/CryptoModeler/.venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
