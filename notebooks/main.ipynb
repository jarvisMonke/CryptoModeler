# %%
import sys
import os
import importlib
import numpy as np
import optuna
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from importlib import reload  # Import the reload function
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import HeNormal
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
from optuna.pruners import SuccessiveHalvingPruner

# %%
# import custom utilities
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils import *

# %%
# Reload all modules in the 'utils' package
for module_name in list(sys.modules.keys()):
    if module_name.startswith('utils'):
        importlib.reload(sys.modules[module_name])

# %%
# Check if TensorFlow is built with CUDA support and is configured to use GPU
print(tf.test.is_built_with_cuda())  # Should return True
print(tf.config.list_physical_devices('GPU'))  # Should list GPU
# Out:
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Calculate the start date based on the end date and a given number of minutes
from datetime import datetime, timedelta

# Define the end date
end_date = datetime(2025, 5, 30)

# Calculate the number of days in 500,000 minutes
minutes = 600000
days = minutes / (24 * 60)

# Calculate the start date
start_date = end_date - timedelta(days=days)

print(f"{minutes} minutes before {end_date.strftime('%Y-%m-%d')} is {start_date.strftime('%Y-%m-%d')}")
# Out:
# 600000 minutes before 2025-05-30 is 2024-04-08

# %%
600000 / 20 / 500
# Out:
# 60.0

# %%
# Download and save a crypto data set
downloads = CryptoDataset('BTCUSDT', '1m', '2024-04-08 00:00:00', '2025-05-30 00:00:00', version='600k')
downloads.fetch()
downloads.save()
# Out:
# Fetched data from 2024-04-08 00:00:00 to 2024-04-08 08:19:00
# Fetched data from 2024-04-08 08:20:00 to 2024-04-08 16:39:00
# Fetched data from 2024-04-08 16:40:00 to 2024-04-09 00:59:00
# Fetched data from 2024-04-09 01:00:00 to 2024-04-09 09:19:00
# Fetched data from 2024-04-09 09:20:00 to 2024-04-09 17:39:00
# Fetched data from 2024-04-09 17:40:00 to 2024-04-10 01:59:00
# Fetched data from 2024-04-10 02:00:00 to 2024-04-10 10:19:00
# Fetched data from 2024-04-10 10:20:00 to 2024-04-10 18:39:00
# Fetched data from 2024-04-10 18:40:00 to 2024-04-11 02:59:00
# Fetched data from 2024-04-11 03:00:00 to 2024-04-11 11:19:00
# Fetched data from 2024-04-11 11:20:00 to 2024-04-11 19:39:00
# Fetched data from 2024-04-11 19:40:00 to 2024-04-12 03:59:00
# Fetched data from 2024-04-12 04:00:00 to 2024-04-12 12:19:00
# Fetched data from 2024-04-12 12:20:00 to 2024-04-12 20:39:00
# Fetched data from 2024-04-12 20:40:00 to 2024-04-13 04:59:00
# Fetched data from 2024-04-13 05:00:00 to 2024-04-13 13:19:00
# Fetched data from 2024-04-13 13:20:00 to 2024-04-13 21:39:00
# Fetched data from 2024-04-13 21:40:00 to 2024-04-14 05:59:00
# Fetched data from 2024-04-14 06:00:00 to 2024-04-14 14:19:00
# Fetched data from 2024-04-14 14:20:00 to 2024-04-14 22:39:00
# Fetched data from 2024-04-14 22:40:00 to 2024-04-15 06:59:00
# Fetched data from 2024-04-15 07:00:00 to 2024-04-15 15:19:00
# Fetched data from 2024-04-15 15:20:00 to 2024-04-15 23:39:00
# Fetched data from 2024-04-15 23:40:00 to 2024-04-16 07:59:00
# Fetched data from 2024-04-16 08:00:00 to 2024-04-16 16:19:00
# Fetched data from 2025-05-19 22:40:00 to 2025-05-20 06:59:00
# Fetched data from 2025-05-20 07:00:00 to 2025-05-20 15:19:00
# Fetched data from 2025-05-20 15:20:00 to 2025-05-20 23:39:00
# Fetched data from 2025-05-20 23:40:00 to 2025-05-21 07:59:00
# Fetched data from 2025-05-21 08:00:00 to 2025-05-21 16:19:00
# Fetched data from 2025-05-21 16:20:00 to 2025-05-22 00:39:00
# Fetched data from 2025-05-22 00:40:00 to 2025-05-22 08:59:00
# Fetched data from 2025-05-22 09:00:00 to 2025-05-22 17:19:00
# Fetched data from 2025-05-22 17:20:00 to 2025-05-23 01:39:00
# Fetched data from 2025-05-23 01:40:00 to 2025-05-23 09:59:00
# Fetched data from 2025-05-23 10:00:00 to 2025-05-23 18:19:00
# Fetched data from 2025-05-23 18:20:00 to 2025-05-24 02:39:00
# Fetched data from 2025-05-24 02:40:00 to 2025-05-24 10:59:00
# Fetched data from 2025-05-24 11:00:00 to 2025-05-24 19:19:00
# Fetched data from 2025-05-24 19:20:00 to 2025-05-25 03:39:00
# Fetched data from 2025-05-25 03:40:00 to 2025-05-25 11:59:00
# Fetched data from 2025-05-25 12:00:00 to 2025-05-25 20:19:00
# Fetched data from 2025-05-25 20:20:00 to 2025-05-26 04:39:00
# Fetched data from 2025-05-26 04:40:00 to 2025-05-26 12:59:00
# Fetched data from 2025-05-26 13:00:00 to 2025-05-26 21:19:00
# Fetched data from 2025-05-26 21:20:00 to 2025-05-27 05:39:00
# Fetched data from 2025-05-27 05:40:00 to 2025-05-27 13:59:00
# Fetched data from 2025-05-27 14:00:00 to 2025-05-27 22:19:00
# Fetched data from 2025-05-27 22:20:00 to 2025-05-28 06:39:00
# Fetched data from 2025-05-28 06:40:00 to 2025-05-28 14:59:00
# Fetched data from 2025-05-28 15:00:00 to 2025-05-28 23:19:00
# Fetched data from 2025-05-28 23:20:00 to 2025-05-29 07:39:00
# Fetched data from 2025-05-29 07:40:00 to 2025-05-29 15:59:00
# Fetched data from 2025-05-29 16:00:00 to 2025-05-29 23:59:00
# No more data within the specified range.
# Dataset saved to data/BTCUSDT_1m_v600k.csv.

# %%
# Sample data (replace with your own data)
# Make sure you have a dataframe with 'timestamp' and 'close' columns
df = pd.read_csv("../data/BTCUSDT_1m_v600k.csv")  # Replace with your actual file
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.set_index('timestamp', inplace=True)

# Resample to a specific timeframe (for example, 5-minute candles)
#df_resampled = df.resample('5T').ohlc()  # '5T' is 5-minute interval

# Create a function to calculate percentage movement for different look-ahead periods
def calculate_percentage_movement(df, look_ahead_values):
    percentage_movements = {}
    
    for look_ahead in look_ahead_values:
        movements = []

        # Loop through each row in the dataset and calculate percentage change for each look-ahead period
        for i in range(len(df) - look_ahead):  # Make sure we don't go out of bounds
            current_price = df['close'].iloc[i]
            future_price = df['close'].iloc[i + look_ahead]
            percentage_movement = ((future_price - current_price) / current_price) * 100
            movements.append(percentage_movement)

        # Store all percentage movements for this look_ahead value
        percentage_movements[look_ahead] = movements
    
    return percentage_movements

# Define different look_ahead periods to test
look_ahead_values = [300, 400, 500, 600]  # Look-ahead periods in number of 1-minute intervals

# Calculate percentage movements
percentage_movements = calculate_percentage_movement(df, look_ahead_values)

# Evaluate statistical metrics (mean, median, variance) for each look_ahead period
look_ahead_stats = {}

for look_ahead in look_ahead_values:
    movements = percentage_movements[look_ahead]
    look_ahead_stats[look_ahead] = {
        'mean': np.mean(movements),
        'median': np.median(movements),
        'std': np.std(movements),
        'variance': np.var(movements)
    }

# Print statistical metrics for each look-ahead period
print("Statistical Metrics for each Look-Ahead Period:")
for look_ahead, stats in look_ahead_stats.items():
    print(f"Look-Ahead {look_ahead * 1} minutes:")
    print(f"  Mean: {stats['mean']:.4f}%")
    print(f"  Median: {stats['median']:.4f}%")
    print(f"  Std Dev: {stats['std']:.4f}%")
    print(f"  Variance: {stats['variance']:.4f}")
    print()

# Plot distribution of percentage movements for each look-ahead period
plt.figure(figsize=(12, 8))

# Plot each look-ahead period's distribution
for look_ahead in look_ahead_values:
    plt.subplot(len(look_ahead_values), 1, look_ahead_values.index(look_ahead) + 1)
    sns.histplot(percentage_movements[look_ahead], kde=True, bins=30, color='blue', stat='density')
    plt.title(f"Distribution of Percentage Movements for Look-Ahead {look_ahead *1} minutes")
    plt.xlabel('Percentage Movement (%)')
    plt.ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# Statistical Metrics for each Look-Ahead Period:
# Look-Ahead 300 minutes:
#   Mean: 0.0284%
#   Median: 0.0297%
#   Std Dev: 1.1962%
#   Variance: 1.4310
#
# Look-Ahead 400 minutes:
#   Mean: 0.0378%
#   Median: 0.0421%
#   Std Dev: 1.3778%
#   Variance: 1.8984
#
# Look-Ahead 500 minutes:
#   Mean: 0.0472%
#   Median: 0.0460%
#   Std Dev: 1.5399%
#   Variance: 2.3712
#
# Look-Ahead 600 minutes:
#   Mean: 0.0563%
#   Median: 0.0524%
#   Std Dev: 1.6861%
#   Variance: 2.8430

# %%
# Objective function for optimization
def objective(trial):

    # MODEL CREATION
    params_grid = {
        # LSTM Units
        "lstm_units_1": trial.suggest_categorical("lstm_units_1", [64, 128, 256]),
        "lstm_units_2": trial.suggest_categorical("lstm_units_2", [32, 64, 128]),

        # Dropout rate for regularization
        "dropout": trial.suggest_categorical("dropout", [0.1, 0.2, 0.3, 0.5]),

        # Learning rate for the optimizer (log scale for better range)
        "learning_rate": trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True),

        # Batch size (common choices)
        "batch_size": trial.suggest_categorical("batch_size", [16, 32, 64, 128]),

        # Dense layer units (for fully connected layers after LSTM)
        "dense_units": trial.suggest_categorical("dense_units", [16, 32, 64, 128]),

        # Sequence length (historical data considered for prediction)
        "sequence_length": trial.suggest_categorical("sequence_length", [10, 20, 50, 100]),

        # Gradient clipping for preventing exploding gradients
        "gradient_clipping": trial.suggest_categorical("gradient_clipping", [0.5, 1.0, 2.0]),

        # Optimizer choice (Adam or RMSprop)
        "optimizer": trial.suggest_categorical("optimizer", ['adam', 'rmsprop']),

        # Activation function for layers
        "activation": trial.suggest_categorical("activation", ['relu', 'tanh'])
    }

    # DATA CREATION AND PROCESSING
    timeframe_filenames = {
    "1m": "../data/raw/ETHUSDT_1m_v600k.csv",
    "3m": "../data/raw/DOGEUSDT_3m_v0.csv",
    "5m": "../data/raw/DOGEUSDT_5m_v0.csv",
    "15m": "../data/raw/DOGEUSDT_15m_v0.csv",
    "30m": "../data/raw/DOGEUSDT_30m_v0.csv"
}
    # Timeframe to trade on
    timeframe = '1m'
    timeframe_file = timeframe_filenames[timeframe]
        
    # The number of indicators to be used in the model
    num_indicators = trial.suggest_int('num_indicators', 5, 46)
    
    # The scaler of the data
    scaler_type = trial.suggest_categorical('scaler', ['MinMaxScaler', 'StandardScaler', 'RobustScaler'])
    
    # How big the look behind window is
    window_size = 80 #trial.suggest_int('window_size', 10, 135)  # Example range for window size
    
    # How far in the future to trade
    look_ahead_size = 20 #trial.suggest_int('look_ahead_size', 5, 50)

    # PROFIT FUNCTION VALUES
    # Create the simulate trading values
    #prediction_tolerance_max = trial.suggest_float('predTolMax', 0.8, 1)
    #prediction_tolerance_min = trial.suggest_float('predTolMin', 0.8, 1)
    # When to trade
    #trade_threshold = trial.suggest_float('trade_threshold', 0.0005, .02)

    # print everthing
    print(f'HyperParams: Timeframe: {timeframe_file}, Num Indicators: {num_indicators}, Scaler: {scaler_type}, Window Size: {window_size}, Look ahead Size: {look_ahead_size}, Dropout: {params_grid}')
    
    # run
    current_model = pipeline()
    current_model.pass_hyperparams(timeframe, num_indicators, scaler_type, window_size, look_ahead_size, params_grid)
    model = current_model.full_stack(trial=trial, filename=timeframe_file)
    
    # Calculate profit per trade per normalized time
    #timeframe_int = int(''.join(filter(str.isdigit, timeframe)))
    #total_profit, total_trades = current_model.full_stack(trial=trial, filename=timeframe_file)

    # Check if the trial is pruned after training
    if trial.should_prune():
        print("Trial pruned after training.")
        raise optuna.exceptions.TrialPruned()
    
    test_loss, test_mae = model.evaluate(current_model.X_test, current_model.y_test, verbose=1)
    
    return test_mae

# %%
# JUST ONE TRIAL

pruner = SuccessiveHalvingPruner(
    min_resource=5,  # Minimum number of steps before evaluating
    reduction_factor=3,  # Fraction of trials to prune at each step
    min_early_stopping_rate=1  # Prevent pruning too early
)
# Create and run the Optuna study
study = optuna.create_study(direction='minimize', pruner=pruner)

study.optimize(objective, n_trials=1)  # Run 1 trial

# Get the best parameters
print("Best parameters:", study.best_params)
# Out:
# [I 2025-01-02 23:51:00,515] A new study created in memory with name: no-name-d4f4a243-1eb7-413c-b62e-578ab61aeb2c
# HyperParams: Timeframe: data/ETHUSDT_1m_v600k.csv, Num Indicators: 14, Scaler: MinMaxScaler, Window Size: 80, Look ahead Size: 20, Dropout: {'lstm_units_1': 64, 'lstm_units_2': 32, 'dropout': 0.2, 'learning_rate': 0.0002725094538786082, 'batch_size': 16, 'dense_units': 64, 'sequence_length': 100, 'gradient_clipping': 1.0, 'optimizer': 'rmsprop', 'activation': 'tanh'}
# Dataset loaded from data/ETHUSDT_1m_v600k.csv.
# Loaded into pipeline.data
# Data Preprocessed!
# Data Split into model and test Sets
# I0000 00:00:1735887080.182492   10466 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0063 - mae: 0.0523 - val_loss: 0.0055 - val_mae: 0.0506
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0059 - mae: 0.0515 - val_loss: 0.0056 - val_mae: 0.0491
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0059 - mae: 0.0501 - val_loss: 0.0038 - val_mae: 0.0457
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0056 - mae: 0.0486 - val_loss: 0.0033 - val_mae: 0.0395
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0061 - mae: 0.0505 - val_loss: 0.0030 - val_mae: 0.0392
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0058 - mae: 0.0501 - val_loss: 0.0030 - val_mae: 0.0378
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0062 - mae: 0.0509 - val_loss: 0.0027 - val_mae: 0.0339
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0059 - mae: 0.0488 - val_loss: 0.0086 - val_mae: 0.0447
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0056 - mae: 0.0483 - val_loss: 0.0114 - val_mae: 0.0553
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0064 - mae: 0.0492 - val_loss: 0.0059 - val_mae: 0.0519
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0070 - mae: 0.0503 - val_loss: 0.0025 - val_mae: 0.0384
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0053 - mae: 0.0464 - val_loss: 0.0023 - val_mae: 0.0342
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0071 - mae: 0.0479 - val_loss: 0.0017 - val_mae: 0.0305
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0046 - mae: 0.0430 - val_loss: 0.0023 - val_mae: 0.0325
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0045 - mae: 0.0423 - val_loss: 0.0023 - val_mae: 0.0260
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0219 - mae: 0.0968
# [I 2025-01-02 23:54:11,129] Trial 0 finished with value: 0.09826568514108658 and parameters: {'lstm_units_1': 64, 'lstm_units_2': 32, 'dropout': 0.2, 'learning_rate': 0.0002725094538786082, 'batch_size': 16, 'dense_units': 64, 'sequence_length': 100, 'gradient_clipping': 1.0, 'optimizer': 'rmsprop', 'activation': 'tanh', 'num_indicators': 14, 'scaler': 'MinMaxScaler'}. Best is trial 0 with value: 0.09826568514108658.
# Best parameters: {'lstm_units_1': 64, 'lstm_units_2': 32, 'dropout': 0.2, 'learning_rate': 0.0002725094538786082, 'batch_size': 16, 'dense_units': 64, 'sequence_length': 100, 'gradient_clipping': 1.0, 'optimizer': 'rmsprop', 'activation': 'tanh', 'num_indicators': 14, 'scaler': 'MinMaxScaler'}

# %%
storage_path = "sqlite:///../optuna/study.db"

#optuna.delete_study(study_name="the_study", storage=storage_path)

pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)

study = optuna.load_study(storage=storage_path, study_name="the_study")

# Create and run the Optuna study
#study = optuna.create_study(storage=storage_path, study_name="the_study", direction='minimize', pruner=pruner)

study.optimize(objective, n_trials=100)  # Run 100 trials

# Get the best parameters
print("Best parameters:", study.best_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 storage_path = "sqlite:///../optuna/study.db"
#       3 #optuna.delete_study(study_name="the_study", storage=storage_path)
# ----> 5 pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)
#       7 study = optuna.load_study(storage=storage_path, study_name="the_study")
#       9 # Create and run the Optuna study
#      10 #study = optuna.create_study(storage=storage_path, study_name="the_study", direction='minimize', pruner=pruner)
#
# NameError: name 'optuna' is not defined

# %%
pass_hyperparams(self, timeframe, num_indicators, scaler_type, window_size, look_ahead_size, params_grid)

# %%
# Objective function for optimization
def custom_model(params):

    # model params
    model_keys = [
    'lstm_units_1', 'lstm_units_2', 'dropout', 'learning_rate', 'batch_size',
    'dense_units', 'sequence_length', 'gradient_clipping', 'optimizer', 'activation'
]
    # Create the new dictionary using dictionary comprehension
    params_grid = {key: params[key] for key in model_keys}

    # Get a file name for the timeframe
    timeframe_filenames = {
    "1m": "data/ETHUSDT_1m_v600k.csv",
    "3m": "data/DOGEUSDT_3m_v0.csv",
    "5m": "data/DOGEUSDT_5m_v0.csv",
    "15m": "data/DOGEUSDT_15m_v0.csv",
    "30m": "data/DOGEUSDT_30m_v0.csv"
}
    timeframe = '1m'
    window_size = 80
    look_ahead_size = 20
    timeframe_file = timeframe_filenames[timeframe]
    
    # run
    current_model = pipeline()
    current_model.pass_hyperparams(timeframe, params['num_indicators'], params['scaler'], window_size, look_ahead_size, params_grid, tuning=False)
    
    current_model.full_stack(trial=0,filename=timeframe_file)
   
    return current_model.model

# %%
params = {'lstm_units_1': 64, 'lstm_units_2': 128, 'dropout': 0.2, 'learning_rate': 0.005326718162056909, 'batch_size': 32, 'dense_units': 16, 'sequence_length': 10, 'gradient_clipping': 0.5, 'optimizer': 'adam', 'activation': 'tanh', 'num_indicators': 16, 'scaler': 'MinMaxScaler'}

model = custom_model(params)
# Out:
# Dataset loaded from data/ETHUSDT_1m_v600k.csv.
# Loaded into pipeline.data
# Data Preprocessed!
# Data Split into model and test Sets
# I0000 00:00:1735943443.876406  230768 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5007 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060, pci bus id: 0000:02:00.0, compute capability: 6.1
# I0000 00:00:1735943447.550518  231041 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1584 - mae: 0.2187
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 params = {'lstm_units_1': 64, 'lstm_units_2': 128, 'dropout': 0.2, 'learning_rate': 0.005326718162056909, 'batch_size': 32, 'dense_units': 16, 'sequence_length': 10, 'gradient_clipping': 0.5, 'optimizer': 'adam', 'activation': 'tanh', 'num_indicators': 16, 'scaler': 'MinMaxScaler'}
# ----> 3 model = custom_model(params)
#
# Cell In[3], line 29, in custom_model(params)
#      26 current_model = pipeline()
#      27 current_model.pass_hyperparams(timeframe, params['num_indicators'], params['scaler'], window_size, look_ahead_size, params_grid, tuning=False)
# ---> 29 current_model.full_stack(trial=0,filename=timeframe_file)
#      31 return current_model.model
#
# File ~/Projects/trading_bot/model_utils.py:625, in pipeline.full_stack(self, trial, filename)
#     623 self.normalize_y_data()
#     624 #total_profit, total_trades, X_test, y_test, y_train, predictions = self.return_profit()
# --> 625 return self.train(trial=trial)
#
# File ~/Projects/trading_bot/model_utils.py:577, in pipeline.train(self, trial, epochs)
#     574 pruning_callback = KerasPruningCallback(trial, 'val_loss')  # Monitor 'val_loss' for pruning
#     576 # Now train the same model on the new data for this epoch (do not reinitialize model)
# --> 577 history = model.fit(
#     578     X_train_epoch,
#     579     y_train_epoch,
#     580     epochs=1,  # Train for 1 epoch at a time in this loop
#     581     batch_size=self.params_grid["batch_size"],
#     582     validation_data=(X_val_epoch, y_val_epoch),  # Provide the new validation data
#     583     verbose=1,
#     584     callbacks=[early_stopping, nan_checker, pruning_callback]
#     585 )
#     587 if self.tuning:
#     588     # Manually increment the Optuna pruning step
#     589     trial.report(history.history['val_loss'][-1], step=epoch_counter)
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/optuna_integration/keras/keras.py:60, in KerasPruningCallback.on_epoch_end(self, epoch, logs)
#      58     warnings.warn(message)
#      59     return
# ---> 60 self._trial.report(float(current_score), step=epoch)
#      61 if self._trial.should_prune():
#      62     message = "Trial was pruned at epoch {}.".format(epoch)
#
# AttributeError: 'int' object has no attribute 'report'

# %%
candles = raw


def get_trade(candles, params, model):
    
    # model params
    model_keys = [
    'lstm_units_1', 'lstm_units_2', 'dropout', 'learning_rate', 'batch_size',
    'dense_units', 'sequence_length', 'gradient_clipping', 'optimizer', 'activation'
]
    # Create the new dictionary using dictionary comprehension
    params_grid = {key: params[key] for key in model_keys}
    
    predictor_model = pipeline()
    predictor_model.pass_hyperparams(params['timeframe'], params['num_indicators'], params['scaler'], params['window_size'], params['look_ahead_size'], params_grid, params['predTolMax'], params['predTolMin'], params['trade_threshold'], 1)

    predictor_model.model = model
    predictor_model.preprocess()

# %%
i = 200

timeframe= '30m'
scaler_type = 'RobustScaler'

look_ahead_size = 40
dropout_rate = .2
num_indicators = 20
prediction_tolerance_max = .95 
prediction_tolerance_min = .95
trade_threshold = .02

while (i > 20):
    modelv1 = pipeline()
    window_size = i
    i -= 5
    print(f"Window Size: {window_size}")
    modelv1.pass_hyperparams(timeframe, num_indicators, scaler_type, window_size, look_ahead_size, dropout_rate, prediction_tolerance_max, prediction_tolerance_min, trade_threshold)

    modelv1.load_file(filename='data/DOGEUSD_30m_vo.csv')
    modelv1.preprocess()
    modelv1.target_creation()
    modelv1.split_data()
    modelv1.train()
# Out:
# Window Size: 200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 18
#      16 i -= 5
#      17 print(f"Window Size: {window_size}")
# ---> 18 modelv1.pass_hyperparams(timeframe, num_indicators, scaler_type, window_size, look_ahead_size, dropout_rate, prediction_tolerance_max, prediction_tolerance_min, trade_threshold)
#      20 modelv1.load_file(filename='data/DOGEUSD_30m_vo.csv')
#      21 modelv1.preprocess()
#
# TypeError: pipeline.pass_hyperparams() missing 1 required positional argument: 'sample_size'

# %%
timeframe= '30m'
num_indicators = 20
scaler_type = 'RobustScaler'
window_size = 151
look_ahead_size = 46
dropout_rate = .49

prediction_tolerance_max = .95 
prediction_tolerance_min = .95
trade_threshold = .02

modelv1 = pipeline()
modelv1.pass_hyperparams(timeframe, num_indicators, scaler_type, window_size, look_ahead_size, dropout_rate, prediction_tolerance_max, prediction_tolerance_min, trade_threshold)

modelv1.load_file(filename='data/DOGEUSD_30m_vo.csv')
modelv1.preprocess()
modelv1.target_creation()
modelv1.split_data()
# Out:
# Dataset loaded from data/DOGEUSD_30m_vo.csv.
# Loaded into pipeline.data
# /home/jonas/Projects/trading_bot/model_utils.py:432: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['close'] = feature_df['close']  # Add the target column back if needed
# Data Preprocessed!
# Data Split!

# %%
np.isnan(modelv1.X_train).any()
# Out:
# np.False_

# %%
modelv1.train()
# Out:
# Epoch 1/50
# 2024-12-25 23:01:14.086057: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 449315600 exceeds 10% of free system memory.
# 1163/1163 ━━━━━━━━━━━━━━━━━━━━ 174s 147ms/step - loss: 46026926833270784.0000 - mae: 8662324.0000 - val_loss: 292779263524864.0000 - val_mae: 274475.2500
# Epoch 2/50
# 1163/1163 ━━━━━━━━━━━━━━━━━━━━ 162s 139ms/step - loss: 6826168418304.0000 - mae: 26561.7988 - val_loss: 12004608000.0000 - val_mae: 4675.8516
# Epoch 3/50
# 1163/1163 ━━━━━━━━━━━━━━━━━━━━ 198s 170ms/step - loss: 52035971081243197440.0000 - mae: 106486480.0000 - val_loss: 6289352196169400320.0000 - val_mae: 118290536.0000
# Epoch 4/50
# 1163/1163 ━━━━━━━━━━━━━━━━━━━━ 181s 155ms/step - loss: 103412006487402217472.0000 - mae: 111667816.0000 - val_loss: 7336033779712.0000 - val_mae: 289142.3438
# Epoch 5/50
# 1163/1163 ━━━━━━━━━━━━━━━━━━━━ 149s 128ms/step - loss: 11993684362919936.0000 - mae: 4984188.0000 - val_loss: 70355142049792.0000 - val_mae: 795298.5000
# Epoch 6/50
#  479/1163 ━━━━━━━━━━━━━━━━━━━━ 1:28 129ms/step - loss: 686727555448832.0000 - mae: 1821143.7500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 modelv1.train()
#
# File ~/Projects/trading_bot/model_utils.py:534, in pipeline.train(self, epochs, batch_size)
#     531             self.model.stop_training = True
#     532 nan_checker = NaNChecker()
# --> 534 history = model.fit(self.X_train, self.y_train, epochs=epochs, batch_size=batch_size,
#     535                 validation_split=0.1,
#     536                 verbose=1, callbacks=[early_stopping, nan_checker])
#     537 self.model = model
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:368, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     366 for step, iterator in epoch_iterator:
#     367     callbacks.on_train_batch_begin(step)
# --> 368     logs = self.train_function(iterator)
#     369     callbacks.on_train_batch_end(step, logs)
#     370     if self.stop_training:
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:216, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     212 def function(iterator):
#     213     if isinstance(
#     214         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     215     ):
# --> 216         opt_outputs = multi_step_on_iterator(iterator)
#     217         if not opt_outputs.has_value():
#     218             raise StopIteration
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~/Projects/trading_bot/.venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
modelv1.load_Model('Scaled')
# Out:
# I0000 00:00:1735018336.286763   11177 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5503 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060, pci bus id: 0000:02:00.0, compute capability: 6.1

# %%
total_profit, X_test, y_test, y_train, predictions = modelv1.return_profit()
# Out:
# 2024-12-23 22:32:19.036227: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 103540000 exceeds 10% of free system memory.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735018339.421893   11456 service.cc:148] XLA service 0x7ed27c006120 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1735018339.421911   11456 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1060, Compute Capability 6.1
# 2024-12-23 22:32:19.448703: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1735018339.560770   11456 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  25/324 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# I0000 00:00:1735018340.007764   11456 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
# Predictions:[[ 0.017639   -0.01618808]
#  [ 0.01709265 -0.01639809]
#  [ 0.03048979 -0.0284367 ]
#  [ 0.02442027 -0.02138515]
#  [ 0.047548   -0.03698634]
#  [ 0.01369887 -0.0134461 ]
#  [ 0.01835247 -0.01714688]
#  [ 0.02041945 -0.02195122]
#  [ 0.01888651 -0.01614244]
#  [ 0.02414487 -0.02079504]]
# Y-Tests:[[ 0.00485437 -0.00970874]
#  [-0.00283286 -0.01983003]
#  [ 0.01490826 -0.03555046]
#  [ 0.02336449  0.00155763]
#  [-0.01451613 -0.14354839]
#  [ 0.00412882 -0.0015139 ]
#  [ 0.06666667  0.00296296]
#  [-0.00286944 -0.06025825]
#  [ 0.0049505  -0.03041018]
#  [ 0.00142349 -0.02918149]]
# TP:[0, 0, np.float32(0.028965302), np.float32(0.023199258), np.float32(0.045170598), 0, 0, np.float32(0.019398475), 0, np.float32(0.022937626)]
# SL:[0, 0, np.float32(-0.027014868), np.float32(-0.02031589), np.float32(-0.035137028), 0, 0, np.float32(-0.02085366), 0, np.float32(-0.019755285)]
# Tot Profit: -57.683440510754934, Wins: 3430, Loses: 1640, No-trade: 5284

# %%
len(predictions)
# Out:
# 10354

# %%
distribution(predictions)
# Out:
# 2024-12-23 22:32:30,170 - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2024-12-23 22:32:30,176 - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2024-12-23 22:32:30,181 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2024-12-23 22:32:30,183 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,183 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,184 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:30,185 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,186 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,186 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,187 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,188 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,189 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,190 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,192 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,193 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2024-12-23 22:32:30,196 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,197 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,198 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,198 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2024-12-23 22:32:30,199 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 1.335
# 2024-12-23 22:32:30,200 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,201 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:30,201 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,202 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:30,203 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:30,206 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,208 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,209 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,210 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,211 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,212 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,213 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,214 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,215 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,216 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,216 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2024-12-23 22:32:30,217 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,218 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,218 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,219 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,219 - DEBUG - findfont: score(FontEntry(fname='/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,220 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDisplay-CondensedItalic.ttf', name='Noto Serif Display', style='italic', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2024-12-23 22:32:30,221 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifHebrew-ExtraCondensedSemiBold.ttf', name='Noto Serif Hebrew', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,221 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansKannada-ExtraCondensed.ttf', name='Noto Sans Kannada', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2024-12-23 22:32:30,222 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentium-basic/GenBasR.ttf', name='Gentium Basic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,223 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-R.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,225 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTeluguUI-Bold.ttf', name='Noto Sans Telugu UI', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,226 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Sawasdee-Bold.ttf', name='Sawasdee', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,227 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedThai-ExtraCondensedBlack.ttf', name='Noto Looped Thai', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,228 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamilSlanted-ExtraLight.ttf', name='Noto Serif Tamil Slanted', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 10.24
# 2024-12-23 22:32:30,229 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDisplay-ExtraCondensedBold.ttf', name='Noto Serif Display', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,229 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCherokee-ExtraBold.ttf', name='Noto Sans Cherokee', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# 2024-12-23 22:32:30,231 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifLao-CondensedBold.ttf', name='Noto Serif Lao', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,232 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifMalayalam-Regular.ttf', name='Noto Serif Malayalam', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,232 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSinhala-CondensedExtraLight.ttf', name='Noto Sans Sinhala', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,233 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGeorgian-CondensedLight.ttf', name='Noto Sans Georgian', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,238 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/Muktibold.ttf', name='Mukti', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,239 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifGurmukhi-Regular.ttf', name='Noto Serif Gurmukhi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,240 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifMalayalam-ExtraBold.ttf', name='Noto Serif Malayalam', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# 2024-12-23 22:32:30,241 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBengali-ExtraCondensedLight.ttf', name='Noto Serif Bengali', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,242 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifMyanmar-Thin.ttf', name='Noto Serif Myanmar', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,244 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerif-ExtraCondensedBlackItalic.ttf', name='Noto Serif', style='italic', variant='normal', weight=900, stretch='condensed', size='scalable')) = 11.725
# 2024-12-23 22:32:30,245 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedLao-ExtraCondensedMedium.ttf', name='Noto Looped Lao', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,246 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansOldItalic-Regular.ttf', name='Noto Sans Old Italic', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,247 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSymbols-Bold.ttf', name='Noto Sans Symbols', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,248 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoRashiHebrew-Regular.ttf', name='Noto Rashi Hebrew', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,249 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstFarsi.ttf', name='KacstFarsi', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,250 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Regular.ttf', name='Lato', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,251 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansElbasan-Regular.ttf', name='Noto Sans Elbasan', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,252 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSoraSompeng-Bold.ttf', name='Noto Sans Sora Sompeng', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,253 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansEthiopic-CondensedBlack.ttf', name='Noto Sans Ethiopic', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,256 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-Roman.otf', name='P052', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,258 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDisplay-ExtraCondensedItalic.ttf', name='Noto Serif Display', style='italic', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2024-12-23 22:32:30,259 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGeorgian-SemiCondensedBold.ttf', name='Noto Sans Georgian', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,261 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansKannada-SemiCondensedMedium.ttf', name='Noto Sans Kannada', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,262 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGujarati-ExtraCondensedBold.ttf', name='Noto Sans Gujarati', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,263 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgMono-BoldOblique.ttf', name='Tlwg Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:30,264 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansEthiopic-ExtraCondensedSemiBold.ttf', name='Noto Sans Ethiopic', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,265 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansKhmer-CondensedBold.ttf', name='Noto Sans Khmer', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,266 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-BI.ttf', name='Ubuntu Mono', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:30,266 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLaoUI-Bold.ttf', name='Noto Sans Lao UI', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,267 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerif-BlackItalic.ttf', name='Noto Serif', style='italic', variant='normal', weight=900, stretch='normal', size='scalable')) = 11.525
# 2024-12-23 22:32:30,268 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifGeorgian-ExtraCondensedSemiBold.ttf', name='Noto Serif Georgian', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,269 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifLao-Condensed.ttf', name='Noto Serif Lao', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2024-12-23 22:32:30,270 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-bengali/Lohit-Bengali.ttf', name='Lohit Bengali', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,271 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSoraSompeng-SemiBold.ttf', name='Noto Sans Sora Sompeng', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2024-12-23 22:32:30,272 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-BlackItalic.ttf', name='Noto Sans Display', style='italic', variant='normal', weight=900, stretch='normal', size='scalable')) = 11.525
# 2024-12-23 22:32:30,274 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/crosextra/Caladea-Regular.ttf', name='Caladea', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,275 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHebrew-CondensedBlack.ttf', name='Noto Sans Hebrew', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,276 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifKhmer-SemiCondensedMedium.ttf', name='Noto Serif Khmer', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,276 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHebrew-SemiCondensedBlack.ttf', name='Noto Sans Hebrew', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,277 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTelugu-ExtraCondensedLight.ttf', name='Noto Sans Telugu', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,278 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifEthiopic-CondensedThin.ttf', name='Noto Serif Ethiopic', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,282 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBamum-Medium.ttf', name='Noto Sans Bamum', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,283 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='condensed', size='scalable')) = 1.535
# 2024-12-23 22:32:30,283 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstLetter.ttf', name='KacstLetter', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,285 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansAvestan-Regular.ttf', name='Noto Sans Avestan', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,286 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBengali-CondensedMedium.ttf', name='Noto Serif Bengali', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,287 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/Bangers-Regular.ttf', name='Bangers', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,289 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDisplay-Regular.ttf', name='Noto Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,292 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSinhala-SemiCondensedLight.ttf', name='Noto Sans Sinhala', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,294 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGujarati-SemiCondensedBold.ttf', name='Noto Sans Gujarati', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,295 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi-Italic.ttf', name='Norasi', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,298 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHebrew-SemiCondensedMedium.ttf', name='Noto Sans Hebrew', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,299 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGujarati-ExtraCondensedThin.ttf', name='Noto Sans Gujarati', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,300 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGurmukhi-ExtraCondensedLight.ttf', name='Noto Sans Gurmukhi', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,301 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThaana-Bold.ttf', name='Noto Sans Thaana', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,303 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/rsfs10.ttf', name='rsfs10', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,304 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTibetan-Light.ttf', name='Noto Serif Tibetan', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,305 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGurmukhi-ExtraLight.ttf', name='Noto Sans Gurmukhi', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 10.24
# 2024-12-23 22:32:30,306 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifHebrew-CondensedBold.ttf', name='Noto Serif Hebrew', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,310 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMeeteiMayek-Light.ttf', name='Noto Sans Meetei Mayek', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,311 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifLao-CondensedExtraBold.ttf', name='Noto Serif Lao', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:30,314 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifThai-CondensedLight.ttf', name='Noto Serif Thai', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,317 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedThai-ExtraCondensedMedium.ttf', name='Noto Looped Thai', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,319 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoKufiArabic-SemiBold.ttf', name='Noto Kufi Arabic', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2024-12-23 22:32:30,325 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThai-SemiCondensedExtraBold.ttf', name='Noto Sans Thai', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:30,331 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamil-CondensedLight.ttf', name='Noto Serif Tamil', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,333 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Medium.ttf', name='Yrsa', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,334 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHebrew-ExtraCondensedExtraLight.ttf', name='Noto Sans Hebrew', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,336 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Laksaman-BoldItalic.ttf', name='Laksaman', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:30,339 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTifinaghTawellemmet-Regular.ttf', name='Noto Sans Tifinagh Tawellemmet', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,345 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMalayalam-CondensedBold.ttf', name='Noto Sans Malayalam', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,346 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-B.ttf', name='Ubuntu', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,347 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTamil-ExtraCondensedExtraLight.ttf', name='Noto Sans Tamil', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,348 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifSinhala-CondensedLight.ttf', name='Noto Serif Sinhala', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,349 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThai-ExtraCondensedThin.ttf', name='Noto Sans Thai', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,350 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGurmukhiUI-Bold.ttf', name='Noto Sans Gurmukhi UI', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,352 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHebrew-Thin.ttf', name='Noto Sans Hebrew', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,353 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThai-Regular.ttf', name='Noto Sans Thai', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,354 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBengaliUI-Regular.ttf', name='Noto Sans Bengali UI', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,358 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifArmenian-CondensedBold.ttf', name='Noto Serif Armenian', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,360 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThaana-Light.ttf', name='Noto Sans Thaana', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,361 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-LightItalic.ttf', name='Noto Sans Display', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2024-12-23 22:32:30,362 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifLao-CondensedBlack.ttf', name='Noto Serif Lao', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,363 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSans-CondensedThin.ttf', name='Noto Sans', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,364 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifEthiopic-SemiCondensedExtraLight.ttf', name='Noto Serif Ethiopic', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,365 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Gargi/Gargi.ttf', name='Gargi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,370 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLao-ExtraCondensedExtraBold.ttf', name='Noto Sans Lao', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:30,374 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMono-CondensedExtraLight.ttf', name='Noto Sans Mono', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,378 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifLao-ExtraCondensedThin.ttf', name='Noto Serif Lao', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,382 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLycian-Regular.ttf', name='Noto Sans Lycian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,387 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBengali-CondensedLight.ttf', name='Noto Serif Bengali', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,389 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Bold.otf', name='Nimbus Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,393 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Gayathri-Bold.otf', name='Gayathri', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,398 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifMyanmar-SemiCondensedThin.ttf', name='Noto Serif Myanmar', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,399 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBengali-Regular.ttf', name='Noto Serif Bengali', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,404 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Purisa-Oblique.ttf', name='Purisa', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,406 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBengali-SemiCondensedSemiBold.ttf', name='Noto Serif Bengali', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,410 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifGeorgian-CondensedExtraLight.ttf', name='Noto Serif Georgian', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,412 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifHebrew-ExtraCondensedMedium.ttf', name='Noto Serif Hebrew', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,414 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTelugu-CondensedLight.ttf', name='Noto Sans Telugu', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,415 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCherokee-ExtraLight.ttf', name='Noto Sans Cherokee', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 10.24
# 2024-12-23 22:32:30,417 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifArmenian-ExtraCondensedMedium.ttf', name='Noto Serif Armenian', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,418 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifLao-SemiCondensedExtraBold.ttf', name='Noto Serif Lao', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:30,420 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThai-CondensedBold.ttf', name='Noto Sans Thai', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,422 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifSinhala-ExtraCondensedExtraBold.ttf', name='Noto Serif Sinhala', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:30,423 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerif-Medium.ttf', name='Noto Serif', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,431 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMono-SemiCondensedBlack.ttf', name='Noto Sans Mono', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,433 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDisplay-ExtraCondensedBlack.ttf', name='Noto Serif Display', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,435 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThai-ExtraCondensedBold.ttf', name='Noto Sans Thai', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,436 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThaiUI-Regular.ttf', name='Noto Sans Thai UI', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,438 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamilSlanted-SemiCondensedBold.ttf', name='Noto Serif Tamil Slanted', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:30,440 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGurmukhi-Condensed.ttf', name='Noto Sans Gurmukhi', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2024-12-23 22:32:30,441 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Manjari-Thin.otf', name='Manjari', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,442 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansEthiopic-ExtraCondensedBlack.ttf', name='Noto Sans Ethiopic', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,443 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,446 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/Peddana-Regular.ttf', name='Peddana', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:30,448 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSans-ExtraCondensedBlack.ttf', name='Noto Sans', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:30,449 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/mathjax/MathJax_SansSerif-Italic.otf', name='MathJax_SansSerif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,450 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHebrew-Condensed.ttf', name='Noto Sans Hebrew', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2024-12-23 22:32:30,451 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedLao-CondensedSemiBold.ttf', name='Noto Looped Lao', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,452 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Manjari-Bold.otf', name='Manjari', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:30,454 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-Italic.otf', name='P052', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:30,457 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansArabic-ExtraCondensedLight.ttf', name='Noto Sans Arabic', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,459 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedThai-ExtraLight.ttf', name='Noto Looped Thai', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 10.24
# 2024-12-23 22:32:30,460 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTamil-ExtraBold.ttf', name='Noto Sans Tamil', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# 2024-12-23 22:32:30,461 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSans-CondensedBoldItalic.ttf', name='Noto Sans', style='italic', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# 2024-12-23 22:32:30,463 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Waree-BoldOblique.ttf', name='Waree', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:30,464 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLao-CondensedExtraLight.ttf', name='Noto Sans Lao', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,465 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedThai-SemiCondensedLight.ttf', name='Noto Looped Thai', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:30,466 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-ExtraCondensedExtraLight.ttf', name='Noto Sans Display', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:30,467 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDevanagari-SemiCondensedExtraBold.ttf', name='Noto Serif Devanagari', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:30,468 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoNaskhArabic-Medium.ttf', name='Noto Naskh Arabic', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:30,470 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGeorgian-ExtraCondensedLight.ttf', name='Noto Sans Georgian', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# ...
# 2024-12-23 22:32:37,583 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTaiTham-Bold.ttf', name='Noto Sans Tai Tham', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:37,584 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedLao-SemiCondensedBlack.ttf', name='Noto Looped Lao', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:37,585 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoNaskhArabic-SemiBold.ttf', name='Noto Naskh Arabic', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2024-12-23 22:32:37,590 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansThai-Thin.ttf', name='Noto Sans Thai', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:37,591 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-L.ttf', name='Ubuntu', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:37,592 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifMyanmar-Black.ttf', name='Noto Serif Myanmar', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2024-12-23 22:32:37,593 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansArabic-SemiCondensedBold.ttf', name='Noto Sans Arabic', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:37,594 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansUgaritic-Regular.ttf', name='Noto Sans Ugaritic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,595 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-SemiCondensedExtraBold.ttf', name='Noto Sans Display', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:37,599 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansOgham-Regular.ttf', name='Noto Sans Ogham', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,600 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBengali-CondensedExtraLight.ttf', name='Noto Serif Bengali', style='normal', variant='normal', weight=200, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:37,601 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGeorgian-Thin.ttf', name='Noto Sans Georgian', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:37,601 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHebrew-CondensedThin.ttf', name='Noto Sans Hebrew', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:37,602 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMedefaidrin-Regular.ttf', name='Noto Sans Medefaidrin', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,603 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Umpush-BoldOblique.ttf', name='Umpush', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-12-23 22:32:37,604 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Italic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:37,606 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifArmenian-ExtraCondensedSemiBold.ttf', name='Noto Serif Armenian', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:37,607 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSinhala-ExtraBold.ttf', name='Noto Sans Sinhala', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# 2024-12-23 22:32:37,608 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifSinhala-CondensedThin.ttf', name='Noto Serif Sinhala', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:37,608 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansArmenian-Light.ttf', name='Noto Sans Armenian', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:37,609 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTaiTham-Regular.ttf', name='Noto Sans Tai Tham', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,611 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDevanagari-Black.ttf', name='Noto Sans Devanagari', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2024-12-23 22:32:37,612 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansKannada-SemiCondensed.ttf', name='Noto Sans Kannada', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2024-12-23 22:32:37,615 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-Oblique.ttf', name='Kinnari', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-12-23 22:32:37,616 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGurmukhi-CondensedSemiBold.ttf', name='Noto Sans Gurmukhi', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:37,618 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBalinese-Medium.ttf', name='Noto Sans Balinese', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:37,619 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCarian-Regular.ttf', name='Noto Sans Carian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,620 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansArabic-Bold.ttf', name='Noto Sans Arabic', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:37,621 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHebrew-CondensedBold.ttf', name='Noto Sans Hebrew', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:37,622 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamil-CondensedSemiBold.ttf', name='Noto Serif Tamil', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:37,623 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifArmenian-CondensedSemiBold.ttf', name='Noto Serif Armenian', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:37,624 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-CondensedThinItalic.ttf', name='Noto Sans Display', style='italic', variant='normal', weight=100, stretch='condensed', size='scalable')) = 11.535
# 2024-12-23 22:32:37,625 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedLao-SemiCondensedLight.ttf', name='Noto Looped Lao', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:37,627 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifEthiopic-CondensedMedium.ttf', name='Noto Serif Ethiopic', style='normal', variant='normal', weight=500, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:37,628 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSans-ExtraCondensedSemiBoldItalic.ttf', name='Noto Sans', style='italic', variant='normal', weight=600, stretch='condensed', size='scalable')) = 11.44
# 2024-12-23 22:32:37,630 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansArmenian-CondensedSemiBold.ttf', name='Noto Sans Armenian', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:37,633 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstPen.ttf', name='KacstPen', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2024-12-23 22:32:37,634 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifHebrew-CondensedSemiBold.ttf', name='Noto Serif Hebrew', style='normal', variant='normal', weight=600, stretch='condensed', size='scalable')) = 10.44
# 2024-12-23 22:32:37,634 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifEthiopic-SemiCondensed.ttf', name='Noto Serif Ethiopic', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2024-12-23 22:32:37,635 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/linux-libertine/LinLibertine_M.otf', name='Linux Libertine Mono O', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,636 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/wasy10.ttf', name='wasy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,639 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSyriac-Regular.ttf', name='Noto Sans Syriac', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,644 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTakri-Regular.ttf', name='Noto Sans Takri', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,647 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansOriya-CondensedBold.ttf', name='Noto Sans Oriya', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:37,648 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansEthiopic-ExtraCondensedLight.ttf', name='Noto Sans Ethiopic', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2024-12-23 22:32:37,652 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Gayathri-Regular.otf', name='Gayathri', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,655 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifArmenian-ExtraCondensedBlack.ttf', name='Noto Serif Armenian', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:37,659 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerif-SemiCondensedMediumItalic.ttf', name='Noto Serif', style='italic', variant='normal', weight=500, stretch='condensed', size='scalable')) = 11.344999999999999
# 2024-12-23 22:32:37,660 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-khmeros-core/KhmerOSsys.ttf', name='Khmer OS System', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,662 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-ExtraCondensedBlack.ttf', name='Noto Sans Display', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:37,668 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifArmenian-Black.ttf', name='Noto Serif Armenian', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2024-12-23 22:32:37,669 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDisplay-ExtraCondensedExtraBold.ttf', name='Noto Serif Display', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:37,670 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/padauk/PadaukBook-Regular.ttf', name='Padauk Book', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,675 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansKannada-Black.ttf', name='Noto Sans Kannada', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2024-12-23 22:32:37,676 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedLao-ExtraCondensedThin.ttf', name='Noto Looped Lao', style='normal', variant='normal', weight=100, stretch='condensed', size='scalable')) = 10.535
# 2024-12-23 22:32:37,678 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDevanagari-Thin.ttf', name='Noto Sans Devanagari', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2024-12-23 22:32:37,678 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifGujarati-Regular.ttf', name='Noto Serif Gujarati', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,683 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSylotiNagri-Regular.ttf', name='Noto Sans Syloti Nagri', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-12-23 22:32:37,685 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTamil-ExtraCondensedBlack.ttf', name='Noto Sans Tamil', style='normal', variant='normal', weight=900, stretch='condensed', size='scalable')) = 10.725
# 2024-12-23 22:32:37,685 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMono-SemiCondensedExtraBold.ttf', name='Noto Sans Mono', style='normal', variant='normal', weight=800, stretch='condensed', size='scalable')) = 10.629999999999999
# 2024-12-23 22:32:37,693 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerif-CondensedLightItalic.ttf', name='Noto Serif', style='italic', variant='normal', weight=300, stretch='condensed', size='scalable')) = 11.344999999999999
# 2024-12-23 22:32:37,695 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBamum-SemiBold.ttf', name='Noto Sans Bamum', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2024-12-23 22:32:37,704 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/home/jonas/Projects/trading_bot/.venv/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %%
# Make predictions
predictions = model.predict(X_test)

# Extract actual mix and max percentage changes
actual_max = [pair[0] for pair in y_test]
actual_min = [pair[1] for pair in y_test]

# Extract predicted max and min percentage changes
predicted_max = predictions[:, 0]
predicted_min = predictions[:, 1]

max_difference = actual_max - predicted_max
# Out:
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step

# %%
import matplotlib.pyplot as plt # This sets the appropriate backend for Jupyter notebooks


import numpy as np

cut = 25
max_difference_cut = [max_difference[i]*100 for i in range(len(max_difference)) if i % cut == 0]

# max cuts
predicted_max_cut = [predicted_max[i]*100 for i in range(len(predicted_max)) if i % cut == 0]
actual_max_cut = [actual_max[i]*100 for i in range(len(actual_max)) if i % cut == 0]

# min cuts
predicted_min_cut = [predicted_min[i]*100 for i in range(len(predicted_min)) if i % cut == 0]
actual_min_cut = [actual_min[i]*100 for i in range(len(actual_min)) if i % cut == 0]

#df = pd.DataFrame(X_test)
#y_test = df.iloc[:, 2].to_numpy()

# Plotting
plt.figure(figsize=(10, 6))  # Optional: Size of the figure
#plt.plot(max_difference_25, label='Variation', color='green')  # Plot actual values
plt.plot(actual_max_cut, label='Actual', color='red')  # Plot actual values
plt.plot(predicted_max_cut, label='Predicted', color='blue')  # Plot predicted values

# Add labels and title
plt.xlabel('Index')  # You can also use time or other labels
plt.ylabel('Value')
plt.title('Actual vs Predicted Values')

# Show legend
plt.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[11], line 7
#
#       4 import numpy as np
#
#       6 cut = 25
#
# ----> 7 max_difference_cut = [max_difference[i]*100 for i in range(len(max_difference)) if i % cut == 0]
#
#       9 # max cuts
#
#      10 predicted_max_cut = [predicted_max[i]*100 for i in range(len(predicted_max)) if i % cut == 0]
#
#
#
# NameError: name 'max_difference' is not defined
